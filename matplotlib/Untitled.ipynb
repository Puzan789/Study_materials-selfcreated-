# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
y=np.array([1,2,4,2,3,3,4,5])
plt.plot(y,'d:r',ms=30)
plt.xlabel("hello")
plt.ylabel("hello world")
plt.show()

# %%
# draeing multiple figures

# %%
x=np.array([0,3,4,2])
y=np.array([4,3,2,1])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([0,3,4,2])
y=np.array([4,3,3,1])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.suptitle("helpme")
# Out:
# Text(0.5, 0.98, 'helpme')

# %%
x=['a','b','c']
y=[4,4,2]
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>
